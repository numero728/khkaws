# %%
import pymysql
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
plt.rcParams['font.family']='Malgun Gothic'
# %matplotlib inline

# %%
data=pd.read_pickle('data/지역별교통사고요약.pkl')
data
# Out:
#            지역  전체사고  어린이사고   어린이사고비중    총인구수  인구1000명당사고  1000명당어린이사고
# 0     강원도 강릉시   888     57  6.418919  213442    4.160381     0.267051
# 1     강원도 고성군   138      9  6.521739   27260    5.062362     0.330154
# 2     강원도 동해시   358     11  3.072626   90522    3.954840     0.121517
# 3     강원도 삼척시   414     21  5.072464   67228    6.158148     0.312370
# 4     강원도 속초시   391     29  7.416880   81786    4.780769     0.354584
# ..        ...   ...    ...       ...     ...         ...          ...
# 223  충청북도 제천시   870     51  5.862069  134617    6.462780     0.378853
# 224  충청북도 증평군   210      8  3.809524   37392    5.616175     0.213950
# 225  충청북도 진천군   516     24  4.651163   81084    6.363771     0.295989
# 226  충청북도 청주시  4949    273  5.516266  839566    5.894712     0.325168
# 227  충청북도 충주시  1364     98  7.184751  210737    6.472523     0.465035
#
# [228 rows x 7 columns]

# %%
data=data.sort_values('인구1000명당사고')
data
# Out:
#             지역  전체사고  어린이사고   어린이사고비중    총인구수  인구1000명당사고  1000명당어린이사고
# 158   인천광역시 동구   154      5  3.246753  408862    0.376655     0.012229
# 202   충청남도 계룡시    55      5  9.090909   42971    1.279933     0.116358
# 162  인천광역시 옹진군    32      0  0.000000   20566    1.555966     0.000000
# 161  인천광역시 연수구   670     50  7.462687  366550    1.827854     0.136407
# 83    경상북도 울릉군    18      0  0.000000    9617    1.871686     0.000000
# ..         ...   ...    ...       ...     ...         ...          ...
# 178   전라남도 영암군   493     22  4.462475   54593    9.030462     0.402982
# 164   전라남도 강진군   321     18  5.607477   35286    9.097092     0.510117
# 147   서울특별시 중구  1184     24  2.027027  126171    9.384090     0.190218
# 102   대구광역시 중구   869     24  2.761795   77421   11.224345     0.309993
# 157  인천광역시 남동구  1937     81  4.181724   64427   30.065035     1.257237
#
# [228 rows x 7 columns]

# %%
fig=plt.figure()
ax=plt.axes()
plt.plot(data['인구1000명당사고'],data['1000명당어린이사고'],'o')

# %%
fig.show()
# Out:
# <ipython-input-7-6ebedab27258>:1: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
